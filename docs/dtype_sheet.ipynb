# %%
import pandas as pd

dtype_map = {
    'patient_id': 'string',
    'age': pd.Int8Dtype(),
    'sex': 'category',
    'bmi': 'float32',
    'systolic_bp': 'float32',
    'diastolic_bp': 'float32',
    'heart_rate': 'float32',
    'temperature_f': 'float32',

    'smoking_status': 'category',
    'alcohol_use': 'category',
    'exercise_level': 'category',
    'insurance_type': 'category',

    'charlson_index': pd.Int8Dtype(),

    'dx_hypertension': pd.Int8Dtype(),
    'dx_type2_diabetes': pd.Int8Dtype(),
    'dx_hyperlipidemia': pd.Int8Dtype(),
    'dx_obesity': pd.Int8Dtype(),
    'dx_coronary_artery_disease': pd.Int8Dtype(),
    'dx_heart_failure': pd.Int8Dtype(),
    'dx_atrial_fibrillation': pd.Int8Dtype(),
    'dx_chronic_kidney_disease': pd.Int8Dtype(),
    'dx_copd': pd.Int8Dtype(),
    'dx_asthma': pd.Int8Dtype(),
    'dx_depression': pd.Int8Dtype(),
    'dx_anxiety': pd.Int8Dtype(),
    'dx_hypothyroidism': pd.Int8Dtype(),
    'dx_osteoarthritis': pd.Int8Dtype(),
    'dx_type1_diabetes': pd.Int8Dtype(),

    'visit_type': 'category',
    'primary_diagnosis': 'category',
    'primary_icd10': 'category',
    'secondary_diagnoses': 'string',
    'secondary_icd10s': 'string',
    'provider_specialty': 'category',

    'test_name': 'category',
    'value': 'float32',
    'unit_x': 'category',
    'reference_low': 'float32',
    'reference_high': 'float32',
    'flag': 'category',
    'is_abnormal': pd.Int8Dtype(),
    'delta_from_normal': 'float32',

    'medication': 'category',
    'dose': 'float32',
    'unit_y': 'category',
    'frequency': 'category',
    'indication': 'category',
    'duration_days': 'float32',
    'is_generic': pd.Int8Dtype(),
    'adherence_pct': 'float32',

    'length_of_stay_days': 'float32',
    'icu_admission': pd.Int8Dtype(),
    'icu_days': 'float32',
    'in_hospital_death': pd.Int8Dtype(),
    'discharge_disposition': 'category',
    'readmitted_30d': pd.Int8Dtype(),
    'days_to_readmission': 'float32',
    'primary_drg': 'category',
    'total_charges_usd': 'float32'
}

date_cols = [
    'visit_date',
    'test_date',
    'start_date',
    'admission_date',
    'discharge_date'
]
